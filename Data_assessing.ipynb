# %%
import pandas as pd
import numpy as np
import re

# %%
adverse  = pd.read_csv("adverse_reactions.csv")
patient = pd.read_csv("patients.csv")
treatment = pd.read_csv("treatments.csv")
treatmentcut = pd.read_csv("treatments_cut.csv")

# %%
patient
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California   92390.0
# 1    2370 University Hill Road          Armstrong    Illinois   61812.0
# 2        1493 Poling Farm Road               York    Nebraska   68467.0
# ...

# %%
treatment
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#      hba1c_change
# 0             NaN
# 1            0.97
# ...

# %%
treatmentcut
# Out:
#    given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0       jožka   resanovič  22u - 30u          -         7.56       7.22
# 1   inunnguaq    heilmann  57u - 67u          -         7.85       7.45
# 2       alwin    svensson  36u - 39u          -         7.78       7.34
# 3         thể       lương          -  61u - 64u         7.64       7.22
# 4      amanda     ribeiro  36u - 44u          -         7.85       7.47
# ..        ...         ...        ...        ...          ...        ...
# 65     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 66      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 67      bernd   schneider  48u - 56u          -         7.74       7.44
# 68      berta  napolitani          -  42u - 44u         7.68       7.21
# 69     armina       sauvé  36u - 46u          -         7.86       7.40
#
#     hba1c_change
# 0           0.34
# 1            NaN
# 2            NaN
# 3           0.92
# ...

# %%
with pd.ExcelWriter("ClinicalTrial.xlsx") as writer:
  patient.to_excel(writer , sheet_name = "patient")
  treatment.to_excel(writer , sheet_name = "treatment")
  treatmentcut.to_excel(writer , sheet_name = "treatmentcut")
  adverse.to_excel(writer , sheet_name= "Adverse")

# %%
patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
treatment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  171 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
patient["patient_id"].duplicated().sum()
# Out:
# 0

# %%
treatment[treatment.duplicated()]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
treatment[treatment.duplicated(subset = ["given_name" , "surname"])]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
treatmentcut[treatmentcut.duplicated(subset = ["given_name" , "surname"])]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, auralin, novodra, hba1c_start, hba1c_end, hba1c_change]
# Index: []

# %%
patient.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
patient[patient.duplicated(subset = ["given_name" , "surname"])]
# Out:
#      patient_id assigned_sex given_name surname          address      city  \
# 229         230         male       John     Doe  123 Main Street  New York
# 237         238         male       John     Doe  123 Main Street  New York
# 244         245         male       John     Doe  123 Main Street  New York
# 251         252         male       John     Doe  123 Main Street  New York
# 277         278         male       John     Doe  123 Main Street  New York
#
#     state  zip_code        country                      contact birthdate  \
# 229    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 237    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 244    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 251    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 277    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
#
#      weight  height   bmi
# 229   180.0      72  24.4
# ...

# %%
patient[patient["height"] == 27]
# Out:
#    patient_id assigned_sex given_name  surname               address    city  \
# 4           5         male        Tim  Neudorf  1428 Turkey Pen Lane  Dothan
#
#   state  zip_code        country                          contact  birthdate  \
# 4    AL   36303.0  United States  334-515-7487TimNeudorf@cuvox.de  2/18/1928
#
#    weight  height   bmi
# 4   192.3      27  26.1

# %%
treatment.describe()
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   280.000000  280.000000    171.000000
# mean      7.985929    7.589286      0.546023
# std       0.568638    0.569672      0.279555
# min       7.500000    7.010000      0.200000
# 25%       7.660000    7.270000      0.340000
# 50%       7.800000    7.420000      0.380000
# 75%       7.970000    7.570000      0.920000
# max       9.950000    9.580000      0.990000

# %%
treatment.sort_values("hba1c_change" , na_position="first")
# Out:
#     given_name      surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika     jindrová  41u - 48u          -         7.63       7.20
# 2     yukitaka     takenaka          -  39u - 36u         7.68       7.25
# 8        saber       ménard          -  54u - 54u         8.08       7.70
# 9         asia      woźniak  30u - 36u          -         7.76       7.37
# 10      joseph          day  29u - 36u          -         7.70       7.19
# ..         ...          ...        ...        ...          ...        ...
# 49     jackson      addison          -  42u - 42u         7.99       7.51
# 17        gina         cain          -  36u - 36u         7.88       7.40
# 32       laura  ehrlichmann          -  43u - 40u         7.95       7.46
# 245         wu         sung          -  47u - 48u         7.61       7.12
# 138    giovana        rocha          -  23u - 21u         7.87       7.38
#
#      hba1c_change
# 0             NaN
# 2             NaN
# 8             NaN
# ...

# %% [markdown]
# ## **Issues with dataset**
#
# 1.**Dirty Data**
#
#
# **Table - Patients**
# * Patient_id = 9 contain a typo in name "Dsvid" instead of "David"  ->   `Accuracy issue`
# * Zip code column has entries with 4 digits -> `Validity issue`
# * State column contain full name as well as abreviation -> `consistency issue`
# * Data missing for 12 patients in address , city, state, zip_code , country , contact  -> `completion issue`
# * Incorrect data type assigned to gender , zip_code , birthdate -> `validity issue`
# *   Duplicate entries by the name of john doe -> `accuracy issue`
# *   One patient has 48 pound weight which is 21 kg. -> `validity issue`
# *   One patient has 27 inches h -> `validity issue`
#
#
# **Table - Treatment & Treatment_cut**
#
#
# *   Given name and surname all is in lower case -> `Consistency issue`
# *   Remove u from the auralin and navodra col -> `Validity issue`
# *   Replace  - with NAN in auralin and navodra col -> `validity issue`
# *   Missing values in hba1c_chage col -> `completion issue`
# *   One duplicate entry by the name joseph day -> `accuracy issue`
# *   in hb1ac_change 9 instead of 4 -> `accuracy issue`
#
#
# **Table Adverse_Reaction**
#
# *   Given name and surname all are in lower case -> `Consistency Issue`
#
# **2. Messy Data**
#
# **Table - Patients**
#
# *  Contact col contain both contact and email
#
# **Table - Treatment' &  'Treatment_cut**
#
#
# *   Auralin and Navodra col should be split two col start dose and end dose
# *   Merge both tables
#
# **Table - Adverse_Reactions**
#
#
# *   This table should not exist independently
#
#
#
#
#
# `First make a copy of original dataset before you start the cleaning process`

# %%
patient_copy = patient.copy()
treatment_copy = treatment.copy()
treatmentcut_copy = treatmentcut.copy()
adverse_copy = adverse.copy()

# %% [markdown]
# **Define**
# Table Patients
# Replace all the missing data with no data
#
# Table treatment and treatmentcut
# subtract  hba1c_start to hba1c_end to get the hba1c_change value
#
# In patients table we will seperate email and contact number

# %%
patient_copy.fillna("No data" , inplace = True)

# %%
patient_copy[patient_copy["contact"] == "No data "]
# Out:
#      patient_id assigned_sex given_name      surname   address      city  \
# 209         210       female     Lalita  Eldarkhanov  No data   No data
# 219         220         male         Mỹ        Quynh  No data   No data
# 230         231       female  Elisabeth      Knudsen  No data   No data
# 234         235       female    Martina    Tománková  No data   No data
# 242         243         male       John      O'Brian  No data   No data
# 249         250         male   Benjamin       Mehler  No data   No data
# 257         258         male        Jin         Kung  No data   No data
# 264         265       female   Wafiyyah       Asfour  No data   No data
# 269         270       female     Flavia   Fiorentino  No data   No data
# 278         279       female   Generosa        Cabán  No data   No data
# 286         287         male      Lewis         Webb  No data   No data
# 296         297       female        Chỉ          Lâm  No data   No data
#
# ...

# %%
treatment_copy.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32

# %%
treatment_copy["hba1c_change"] = treatment_copy["hba1c_start"] - treatment_copy["hba1c_end"]
treatmentcut_copy["hba1c_change"] = treatmentcut_copy["hba1c_start"] - treatmentcut_copy["hba1c_end"]

# %%
treatment_copy.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0          0.43
# 1          0.47
# 2          0.43
# 3          0.35
# 4          0.32

# %%
patient_copy
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California  92390.0
# 1    2370 University Hill Road          Armstrong    Illinois  61812.0
# 2        1493 Poling Farm Road               York    Nebraska  68467.0
# ...

# %%
patient_copy["contact"]
# Out:
# 0                 951-719-9170ZoeWellish@superrito.com
# 1                PamelaSHill@cuvox.de+1 (217) 569-3204
# 2                     402-363-6804JaeMDebord@gustr.com
# 3           PhanBaLiem@jourrapide.com+1 (732) 636-8246
# 4                      334-515-7487TimNeudorf@cuvox.de
#                             ...
# 498        207-477-0579MustafaLindstrom@jourrapide.com
# 499                 928-284-4492RumanBisliev@gustr.com
# 500              816-223-6007JinkedeKeizer@teleworm.us
# 501    ChidaluOnyekaozulu@jourrapide.com1 360 443 2060
# 502               PatrickGersten@rhyta.com402-848-4923
# Name: contact, Length: 503, dtype: object

# %%
patient_copy
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California  92390.0
# 1    2370 University Hill Road          Armstrong    Illinois  61812.0
# 2        1493 Poling Farm Road               York    Nebraska  68467.0
# ...
